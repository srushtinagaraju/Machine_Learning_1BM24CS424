# %% [markdown]
# <a href="https://colab.research.google.com/github/srushtinagaraju/Machine_Learning_1BM24CS424/blob/main/1BM24CS424_Lab-3%20Linear_Multiple_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

df = pd.read_csv("canada_per_capita_income.csv")

X = df[['year']]
y = df['per capita income (US$)']

model = LinearRegression()
model.fit(X, y)

test = pd.DataFrame([[2020]], columns=['year'])
prediction = model.predict(test)

print(prediction[0])
# Out:
# 41288.69409441762

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("canada_per_capita_income.csv")

x = df['year'].values
y = df['per capita income (US$)'].values

n = len(x)

b1 = (n*np.sum(x*y) - np.sum(x)*np.sum(y)) / (n*np.sum(x*x) - (np.sum(x))**2)
b0 = (np.sum(y) - b1*np.sum(x)) / n

pred = b0 + b1*2020
print("Predicted income:", pred)
# Out:
# Predicted income: 41288.69409441785

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

df = pd.read_csv("salary.csv")

df['YearsExperience'] = df['YearsExperience'].fillna(df['YearsExperience'].mean())

X = df[['YearsExperience']]
y = df['Salary']

model = LinearRegression()
model.fit(X,y)

test = pd.DataFrame([[12]], columns=['YearsExperience'])
pred = model.predict(test)

print(pred[0])
# Out:
# 139980.88923969213

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("salary.csv")

x = df['YearsExperience'].values
y = df['Salary'].values

n = len(x)

b1 = (n*np.sum(x*y)-np.sum(x)*np.sum(y))/(n*np.sum(x*x)-(np.sum(x))**2)
b0 = (np.sum(y)-b1*np.sum(x))/n

pred = b0 + b1*12
print("Predicted salary:", pred)
# Out:
# Predicted salary: nan

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

df = pd.read_csv("hiring.csv")

mapping = {
    'zero':0,'one':1,'two':2,'three':3,'four':4,
    'five':5,'six':6,'seven':7,'eight':8,'nine':9,
    'ten':10,'eleven':11,'twelve':12
}

df['experience'] = df['experience'].map(mapping)
df['experience'] = df['experience'].fillna(0)
df['test_score(out of 10)'] = df['test_score(out of 10)'].fillna(df['test_score(out of 10)'].mean())

X = df[['experience','test_score(out of 10)','interview_score(out of 10)']]
y = df['salary($)']

model = LinearRegression()
model.fit(X,y)

test1 = pd.DataFrame([[2,9,6]], columns=X.columns)
test2 = pd.DataFrame([[12,10,10]], columns=X.columns)

print(model.predict(test1)[0])
print(model.predict(test2)[0])
# Out:
# 53290.892559447646
# 92268.07227783566

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("hiring.csv")

mapping = {
    'zero':0,'one':1,'two':2,'three':3,'four':4,
    'five':5,'six':6,'seven':7,'eight':8,'nine':9,
    'ten':10,'eleven':11,'twelve':12
}

df['experience'] = df['experience'].map(mapping)
df = df.fillna(0)

X = df[['experience','test_score(out of 10)','interview_score(out of 10)']].values
y = df['salary($)'].values

X = np.c_[np.ones(X.shape[0]), X]

beta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

def predict(a,b,c):
    return beta[0] + beta[1]*a + beta[2]*b + beta[3]*c

print(predict(2,9,6))
print(predict(12,10,10))
# Out:
# 52688.25222797293
# 92940.63332618724

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression

df = pd.read_csv("1000_Companies.csv")

le = LabelEncoder()
df['State'] = le.fit_transform(df['State'])

X = df[['R&D Spend','Administration','Marketing Spend','State']]
y = df['Profit']

model = LinearRegression()
model.fit(X,y)

state = le.transform(['Florida'])[0]

test = pd.DataFrame([[91694.48,515841.3,11931.24,state]],
                    columns=X.columns)

pred = model.predict(test)

print(pred[0])
# Out:
# 511209.20332291996

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

df = pd.read_csv("1000_Companies.csv")

le = LabelEncoder()
df['State'] = le.fit_transform(df['State'])

X = df[['R&D Spend','Administration','Marketing Spend','State']].values
y = df['Profit'].values

X = np.c_[np.ones(X.shape[0]), X]

beta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

state = le.transform(['Florida'])[0]

pred = beta[0] + beta[1]*91694.48 + beta[2]*515841.3 + beta[3]*11931.24 + beta[4]*state
print("Predicted profit:", pred)
# Out:
# Predicted profit: 511209.20332291216
